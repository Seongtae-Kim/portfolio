# %%
import pickle
articles = pickle.load(open("./articles_url.pkl", "rb"))
len(articles)
# Out:
# 1633643

# %%
test = list(articles.keys())

# %%
mentions = {}
for url in test:
    if not len(articles[url]) in mentions:
        mentions[len(articles[url])] = 1
    else:
        mentions[len(articles[url])]+=1

# %%
mentions
# Out:
# {1: 759647,
#  2: 463076,
#  3: 245738,
#  6: 14808,
#  4: 103133,
#  5: 38592,
#  7: 5335,
#  9: 767,
#  11: 127,
#  13: 35,
#  8: 2013,
#  10: 295,
#  12: 61,
#  15: 3,
#  17: 1,
#  14: 11,
#  16: 1}

# %%
articles["https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=052&aid=0001409124"]
# Out:
# [{'date': '20200303', 'keyword': '사회적 거리두기'},
#  {'date': '20200303', 'keyword': '드라이브 스루'},
#  {'date': '20200303', 'keyword': '우한'},
#  {'date': '20200303', 'keyword': '거브러여수스'},
#  {'date': '20200303', 'keyword': '이만희'},
#  {'date': '20200303', 'keyword': '코로나19'},
#  {'date': '20200303', 'keyword': 'WHO'},
#  {'date': '20200303', 'keyword': 'CDC'},
#  {'date': '20200303', 'keyword': '신천지'},
#  {'date': '20200303', 'keyword': '바이러스'},
#  {'date': '20200303', 'keyword': '감염병'},
#  {'date': '20200303', 'keyword': '확진자'}]

# %%
import json
json4 = json.load(open("./articles/articles4.json", "r", encoding="UTF-8-sig"))

# %%
for i in json4:
    print(i, json4[i]["title"])
    if int(i) > 100:
        break
# Out:
# 1 코로나19로 사라진 '캠퍼스 낭만'...대학가 다시 '멈춤'
# 2 금융권, 클라우드 도입 속도전..기술 스타트업 후방효과 톡톡
# 3 안은미컴퍼니 신작 '나는 스무살입니다' 네이버TV에서 본다
# 4 GC녹십자, '제1회 노발락 랜선 토크콘서트' 개최
# 5 경남도 소방본부, 현장대원 심리치료·상담 강화
# 6 인디씬 아이콘 모트, 새 노래 ‘비행기 모드’ 22일 발매
# 7 미래세대 위한 청소년 교육 강화하는 삼성전자
# 8 [기고] 세계1위 디지털정부 대한민국
# 9 홍성재 한성대 교수 '중소벤처기업부 장관상' 수상
# 10 지스타만 온라인 흥행? ‘컴투스 서머너즈워 세계대회’도 성공적 마무리
# 11 [뉴스초점] 코로나19 어제 330명 확진…누적 3만733명
# 12 개인 수목원에 지자체 '혈세'로 3400주 나무 심어…특혜 논란
# 13 동물의 숲, 타임지 선정 '올해 최고 발명품 100'에 이름 올려
# 14 6.25전쟁 70주년 기념 100만 온라인 희망전진대회
# 15 수은 "ESG 확산 핵심 목표…수출 6000억 달러 탈환"
# 16 [교육소식] 건양사이버대 사회통합프로그램 강사워크숍 등
# 17 코로나 방역 목표물 찾아내 소독하는 국산 자율주행 방역로봇 '첫선'
# 18 코로나19 타격 '에듀테크'로 버틴 웅진씽크빅
# 19 비용절감 고심인 카드사, 온라인 채널 늘리고 모집인 줄였다
# 20 문맹보다 무섭다는 금융문맹…DGB금융체험파크에서 재미있게 배워요
# 21 한학자 총재 창설자 특별연설
# 22 홍콩대표 청, ‘서머너즈워’ 월드 챔프 등극
# 23 정부부처 주간일정 및 보도계획(23~27일)
# 24 현대·기아차, 코로나 뚫고 글로벌 가동률 반등
# 25 코로나재확산에도 文대통령 강조한 '국가 간 인력이동', G20선언문에 담긴다
# 26 학교·학원발 무더기 감염…"접촉 줄여야"
# 27 농산물 도매시장 모바일 직거래… ‘식자재 아마존’ 꿈꾼다 [유망 중기·스타트업 'Why Pick']
# ...

# %%
json4["13"]
# Out:
# {'title': "동물의 숲, 타임지 선정 '올해 최고 발명품 100'에 이름 올려",
#  'keywords': ['비대면'],
#  'date': ['20201122'],
#  'datetime': None,
#  'press': '게임메카',
#  'url': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=356&aid=0000043763',
# ...

# %%
json4["101"]
# Out:
# {'title': 'KB국민은행, KB스마트기업대출 서비스 구축',
#  'keywords': ['비대면'],
#  'date': ['20201123'],
#  'datetime': None,
#  'press': '디지털타임스',
#  'url': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002638357',
# ...
